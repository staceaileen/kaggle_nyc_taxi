# %% [markdown]
# # Kaggle: New York City Taxi Fare Prediction
# > the competition's link can be found __[here](https://www.kaggle.com/c/new-york-city-taxi-fare-prediction)__

# %% [markdown]
# ### Helpful articles:
# - __[modeling](https://towardsdatascience.com/train-test-split-and-cross-validation-in-python-80b61beca4b6)__
# - __[markdown](https://medium.com/ibm-data-science-experience/markdown-for-jupyter-notebooks-cheatsheet-386c05aeebed)__

# %%
import numpy as np
import pandas as pd
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
import datetime

# %%
train = pd.read_csv("train.csv")

# %%
test = pd.read_csv("test.csv")

# %%
train.head()
# Out:
#                              key  fare_amount          pickup_datetime  \
# 0    2009-06-15 17:26:21.0000001          4.5  2009-06-15 17:26:21 UTC
# 1    2010-01-05 16:52:16.0000002         16.9  2010-01-05 16:52:16 UTC
# 2   2011-08-18 00:35:00.00000049          5.7  2011-08-18 00:35:00 UTC
# 3    2012-04-21 04:30:42.0000001          7.7  2012-04-21 04:30:42 UTC
# 4  2010-03-09 07:51:00.000000135          5.3  2010-03-09 07:51:00 UTC
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.844311        40.721319         -73.841610         40.712278
# 1        -74.016048        40.711303         -73.979268         40.782004
# 2        -73.982738        40.761270         -73.991242         40.750562
# 3        -73.987130        40.733143         -73.991567         40.758092
# 4        -73.968095        40.768008         -73.956655         40.783762
#
#    passenger_count
# 0                1
# 1                1
# 2                2
# 3                1
# 4                1

# %%
train.info()

# %%
train.drop(columns=['key'], inplace=True)

# %%
train['pickup_datetime'].fillna("0000-00-00 00:00:00 UTC", inplace=True)
train.fillna(-9999, inplace=True)

# %%
train.head()
# Out:
#    fare_amount          pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          4.5  2009-06-15 17:26:21 UTC        -73.844311        40.721319
# 1         16.9  2010-01-05 16:52:16 UTC        -74.016048        40.711303
# 2          5.7  2011-08-18 00:35:00 UTC        -73.982738        40.761270
# 3          7.7  2012-04-21 04:30:42 UTC        -73.987130        40.733143
# 4          5.3  2010-03-09 07:51:00 UTC        -73.968095        40.768008
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.841610         40.712278                1
# 1         -73.979268         40.782004                1
# 2         -73.991242         40.750562                2
# 3         -73.991567         40.758092                1
# 4         -73.956655         40.783762                1

# %%
train.dtypes
# Out:
# fare_amount          float64
# pickup_datetime       object
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count        int64
# dtype: object

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55423480 entries, 0 to 55423855
# Data columns (total 7 columns):
# fare_amount          float64
# pickup_datetime      object
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count      int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 3.3+ GB

# %%
train['pickup_datetime'] = train['pickup_datetime'].map(lambda x: str(x)[:-4])

# %%
train.head()
# Out:
#    fare_amount      pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          4.5  2009-06-15 17:26:21        -73.844311        40.721319
# 1         16.9  2010-01-05 16:52:16        -74.016048        40.711303
# 2          5.7  2011-08-18 00:35:00        -73.982738        40.761270
# 3          7.7  2012-04-21 04:30:42        -73.987130        40.733143
# 4          5.3  2010-03-09 07:51:00        -73.968095        40.768008
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.841610         40.712278                1
# 1         -73.979268         40.782004                1
# 2         -73.991242         40.750562                2
# 3         -73.991567         40.758092                1
# 4         -73.956655         40.783762                1

# %%
train['date'] = train['pickup_datetime'].map(lambda x: str(x)[:10])
train['time'] = train['pickup_datetime'].map(lambda x: str(x)[-8:])
train.head()
# Out:
#    fare_amount      pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          4.5  2009-06-15 17:26:21        -73.844311        40.721319
# 1         16.9  2010-01-05 16:52:16        -74.016048        40.711303
# 2          5.7  2011-08-18 00:35:00        -73.982738        40.761270
# 3          7.7  2012-04-21 04:30:42        -73.987130        40.733143
# 4          5.3  2010-03-09 07:51:00        -73.968095        40.768008
#
#    dropoff_longitude  dropoff_latitude  passenger_count        date      time
# 0         -73.841610         40.712278                1  2009-06-15  17:26:21
# 1         -73.979268         40.782004                1  2010-01-05  16:52:16
# 2         -73.991242         40.750562                2  2011-08-18  00:35:00
# 3         -73.991567         40.758092                1  2012-04-21  04:30:42
# 4         -73.956655         40.783762                1  2010-03-09  07:51:00

# %%
train['year'] = pd.DatetimeIndex(train['date']).year
train['month'] = pd.DatetimeIndex(train['date']).month
train['day'] = pd.DatetimeIndex(train['date']).day
train.head()
# Out:
#    fare_amount      pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          4.5  2009-06-15 17:26:21        -73.844311        40.721319
# 1         16.9  2010-01-05 16:52:16        -74.016048        40.711303
# 2          5.7  2011-08-18 00:35:00        -73.982738        40.761270
# 3          7.7  2012-04-21 04:30:42        -73.987130        40.733143
# 4          5.3  2010-03-09 07:51:00        -73.968095        40.768008
#
#    dropoff_longitude  dropoff_latitude  passenger_count        date      time  \
# 0         -73.841610         40.712278                1  2009-06-15  17:26:21
# 1         -73.979268         40.782004                1  2010-01-05  16:52:16
# 2         -73.991242         40.750562                2  2011-08-18  00:35:00
# 3         -73.991567         40.758092                1  2012-04-21  04:30:42
# 4         -73.956655         40.783762                1  2010-03-09  07:51:00
#
#    year  month  day
# 0  2009      6   15
# 1  2010      1    5
# 2  2011      8   18
# 3  2012      4   21
# 4  2010      3    9

# %%
train['date'] = pd.to_datetime(train['date'])
train['day_of_week'] = train['date'].dt.weekday_name
train.head()
# Out:
#    fare_amount      pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          4.5  2009-06-15 17:26:21        -73.844311        40.721319
# 1         16.9  2010-01-05 16:52:16        -74.016048        40.711303
# 2          5.7  2011-08-18 00:35:00        -73.982738        40.761270
# 3          7.7  2012-04-21 04:30:42        -73.987130        40.733143
# 4          5.3  2010-03-09 07:51:00        -73.968095        40.768008
#
#    dropoff_longitude  dropoff_latitude  passenger_count       date      time  \
# 0         -73.841610         40.712278                1 2009-06-15  17:26:21
# 1         -73.979268         40.782004                1 2010-01-05  16:52:16
# 2         -73.991242         40.750562                2 2011-08-18  00:35:00
# 3         -73.991567         40.758092                1 2012-04-21  04:30:42
# 4         -73.956655         40.783762                1 2010-03-09  07:51:00
#
#    year  month  day day_of_week
# 0  2009      6   15      Monday
# 1  2010      1    5     Tuesday
# 2  2011      8   18    Thursday
# 3  2012      4   21    Saturday
# 4  2010      3    9     Tuesday

# %%
train['hour'] = train['time'].map(lambda x: str(x)[:2])
train.drop(columns=['pickup_datetime', 'date', 'time'], inplace=True)
train.head()

# %%
train['day_of_week'] = pd.factorize(train['day_of_week'])[0] + 1
train.head()

# %%
sample = train[:10000000]

# %%
y = sample['fare_amount']

# %%
X_train, X_test, y_train, y_test = train_test_split(sample, y, test_size=0.2)

# %%
lm = linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
predictions = lm.predict(X_test)

# %%
predictions
# Out:
# array([10.9, 16.5,  7.7, ...,  6.5, 18.5,  9.3])

# %%
mean_squared_error(y_test, predictions)
# Out:
# 1.0556349813525356e-23

# %% [markdown]
# ### Preparing test data to produce submission

# %%
test_key_col = test['key']
test['pickup_datetime'].fillna("0000-00-00 00:00:00 UTC", inplace=True)
test.fillna(-9999, inplace=True)
test.drop(columns=['key'], inplace=True)
test['pickup_datetime'] = test['pickup_datetime'].map(lambda x: str(x)[:-4])
test['date'] = test['pickup_datetime'].map(lambda x: str(x)[:10])
test['time'] = test['pickup_datetime'].map(lambda x: str(x)[-8:])
test['year'] = pd.DatetimeIndex(test['date']).year
test['month'] = pd.DatetimeIndex(test['date']).month
test['day'] = pd.DatetimeIndex(test['date']).day
test['date'] = pd.to_datetime(test['date'])
test['day_of_week'] = test['date'].dt.weekday_name
test['hour'] = test['time'].map(lambda x: str(x)[:2])
test.drop(columns=['pickup_datetime', 'date', 'time'], inplace=True)
test['day_of_week'] = pd.factorize(test['day_of_week'])[0] + 1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-03073a59667b> in <module>()
# ----> 1 train.dropna(inplace=True)
#       2 train.drop(columns=['key'], inplace=True)
#       3 train['pickup_datetime'] = train['pickup_datetime'].map(lambda x: str(x)[:-4])
#       4 train['date'] = train['pickup_datetime'].map(lambda x: str(x)[:10])
#       5 train['time'] = train['pickup_datetime'].map(lambda x: str(x)[-8:])
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    3490                 agg_obj = self.take(indices, axis=agg_axis)
#    3491
# -> 3492             count = agg_obj.count(axis=agg_axis)
#    3493
#    3494             if thresh is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in count(self, axis, level, numeric_only)
#    5642             result = Series(0, index=frame._get_agg_axis(axis))
#    5643         else:
# -> 5644             if frame._is_mixed_type:
#    5645                 result = notna(frame).sum(axis=axis)
#    5646             else:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _is_mixed_type(self)
#    3711     def _is_mixed_type(self):
#    3712         f = lambda: self._data.is_mixed_type
# -> 3713         return self._protect_consolidate(f)
#    3714
#    3715     @property
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _protect_consolidate(self, f)
#    3664         """
#    3665         blocks_before = len(self._data.blocks)
# -> 3666         result = f()
#    3667         if len(self._data.blocks) != blocks_before:
#    3668             self._clear_item_cache()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in <lambda>()
#    3710     @property
#    3711     def _is_mixed_type(self):
# -> 3712         f = lambda: self._data.is_mixed_type
#    3713         return self._protect_consolidate(f)
#    3714
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in is_mixed_type(self)
#    3538     def is_mixed_type(self):
#    3539         # Warning, consolidation needs to get checked upstairs
# -> 3540         self._consolidate_inplace()
#    3541         return len(self.blocks) > 1
#    3542
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in _consolidate_inplace(self)
#    3829     def _consolidate_inplace(self):
#    3830         if not self.is_consolidated():
# -> 3831             self.blocks = tuple(_consolidate(self.blocks))
#    3832             self._is_consolidated = True
#    3833             self._known_consolidated = True
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in _consolidate(blocks)
#    4851     for (_can_consolidate, dtype), group_blocks in grouper:
#    4852         merged_blocks = _merge_blocks(list(group_blocks), dtype=dtype,
# -> 4853                                       _can_consolidate=_can_consolidate)
#    4854         new_blocks = _extend_blocks(merged_blocks, new_blocks)
#    4855     return new_blocks
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in _merge_blocks(blocks, dtype, _can_consolidate)
#    4874
#    4875         argsort = np.argsort(new_mgr_locs)
# -> 4876         new_values = new_values[argsort]
#    4877         new_mgr_locs = new_mgr_locs[argsort]
#    4878
#
# KeyboardInterrupt:

# %%
test_pred
